# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans,AgglomerativeClustering,DBSCAN,SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn import tree
from sklearn import metrics
from ydata_profiling import ProfileReport
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load dataset

# %%
df = pd.read_csv("Customer_Data.csv")

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)

# %%
# profile.to_file("report.html")
# profile

# %% [markdown]
# ### Display general information about the dataset

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.tail()
# Out:
#      CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8945  C19186   28.493517           1.000000     291.12              0.00
# 8946  C19187   19.183215           1.000000     300.00              0.00
# 8947  C19188   23.398673           0.833333     144.40              0.00
# 8948  C19189   13.457564           0.833333       0.00              0.00
# 8949  C19190  372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 8945                    0.000000                          0.833333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe().T
# Out:
#                                    count         mean          std        min  \
# BALANCE                           8950.0  1564.474828  2081.531879   0.000000
# BALANCE_FREQUENCY                 8950.0     0.877271     0.236904   0.000000
# PURCHASES                         8950.0  1003.204834  2136.634782   0.000000
# ONEOFF_PURCHASES                  8950.0   592.437371  1659.887917   0.000000
# INSTALLMENTS_PURCHASES            8950.0   411.067645   904.338115   0.000000
# CASH_ADVANCE                      8950.0   978.871112  2097.163877   0.000000
# PURCHASES_FREQUENCY               8950.0     0.490351     0.401371   0.000000
# ONEOFF_PURCHASES_FREQUENCY        8950.0     0.202458     0.298336   0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  8950.0     0.364437     0.397448   0.000000
# CASH_ADVANCE_FREQUENCY            8950.0     0.135144     0.200121   0.000000
# CASH_ADVANCE_TRX                  8950.0     3.248827     6.824647   0.000000
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
df.drop(['CUST_ID'], axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df['MINIMUM_PAYMENTS'] = df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean())
df['CREDIT_LIMIT'] = df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].mean())

# %%
df.isna().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# BALANCE                             8871
# BALANCE_FREQUENCY                     43
# PURCHASES                           6203
# ONEOFF_PURCHASES                    4014
# INSTALLMENTS_PURCHASES              4452
# CASH_ADVANCE                        4323
# PURCHASES_FREQUENCY                   47
# ONEOFF_PURCHASES_FREQUENCY            47
# PURCHASES_INSTALLMENTS_FREQUENCY      47
# CASH_ADVANCE_FREQUENCY                54
# CASH_ADVANCE_TRX                      65
# PURCHASES_TRX                        173
# CREDIT_LIMIT                         206
# PAYMENTS                            8711
# MINIMUM_PAYMENTS                    8637
# PRC_FULL_PAYMENT                      47
# TENURE                                 7
# dtype: int64

# %%
plt.figure(figsize=(30, 45))
for i, col in enumerate(df.columns):
    if df[col].dtype != 'object':
        ax = plt.subplot(9, 2, i+1)
        sns.kdeplot(df[col],ax=ax)
        plt.xlabel(col)
plt.show()

# %%
plt.figure(figsize=(10,60))
for i in range(0,17):
    plt.subplot(17,1,i+1)
    sns.distplot(df[df.columns[i]],kde_kws={'color':'b','bw': 0.1,'lw':3,'label':'KDE'},hist_kws={'color':'g'})
    plt.title(df.columns[i])
plt.tight_layout()

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Scale the data

# %%
scalar = StandardScaler()
scaled_df = scalar.fit_transform(df)

# %% [markdown]
# ### Dimensionality reduction

# %% [markdown]
# Convert the data to 2D using PCA to visualize the data

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_df)
pca_df = pd.DataFrame(data=principal_components ,columns=["PCA1","PCA2"])
pca_df
# Out:
#           PCA1      PCA2
# 0    -1.682222 -1.076451
# 1    -1.138304  2.506473
# 2     0.969696 -0.383542
# 3    -0.873631  0.043165
# 4    -1.599434 -0.688580
# ...        ...       ...
# 8945 -0.359629 -2.016141
# 8946 -0.564367 -1.639118
# 8947 -0.926203 -1.810781
# 8948 -2.336553 -0.657954
# 8949 -0.556417 -0.400468
#
# [8950 rows x 2 columns]

# %% [markdown]
# ### Find the optimal number of clusters using the elbow method

# %%
inertia = []
range_val = range(1,15)
for i in range_val:
    kmean = KMeans(n_clusters=i)
    kmean.fit_predict(pd.DataFrame(scaled_df))
    inertia.append(kmean.inertia_)
plt.plot(range_val,inertia,'bx-')
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.show()

# %% [markdown]
# ## Using KMeans

# %% [markdown]
# #! try 11 clusters

# %%
kmeans_model=KMeans(4)
kmeans_model.fit_predict(scaled_df)
pca_df_kmeans= pd.concat([pca_df,pd.DataFrame({'CLUSTER':kmeans_model.labels_})],axis=1)

# %% [markdown]
# ## Visualize the clusters

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='PCA1',y='PCA2',hue='CLUSTER',data=pca_df_kmeans,palette=['red','blue','green','yellow'])
plt.title('KMeans Clustering')
plt.show()

# %%
centroids = pd.DataFrame(data=kmeans_model.cluster_centers_,columns=[df.columns])
# inverse transform the centroids to get the actual values
centroids = scalar.inverse_transform(centroids)
centroids = pd.DataFrame(data=centroids,columns=[df.columns])
centroids
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0   890.526458          0.934379  1229.977441       590.034325
# 1  3538.323234          0.987068  7628.896482      5057.499133
# 2  1012.351005          0.789911   269.800322       209.902555
# 3  4601.214652          0.968442   503.252902       320.970734
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0             640.217574   209.297616            0.884592
# 1            2572.843133   650.374765            0.946992
# 2              60.165058   596.359298            0.169751
# 3             182.366964  4518.911273            0.288255
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.296196                         0.711238
# 1                   0.737181                         0.789518
# 2                   0.086305                         0.080176
# 3                   0.139165                         0.185987
#
# ...

# %%
clustered_df = pd.concat([df,pd.DataFrame({'CLUSTER':kmeans_model.labels_})],axis=1)
clustered_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_1 = clustered_df[clustered_df['CLUSTER']==0]
cluster_1.head()
# Out:
#         BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2   2495.148862                1.0     773.17            773.17
# 5   1809.828751                1.0    1333.28              0.00
# 7   1823.652743                1.0     436.20              0.00
# 10  1293.124939                1.0     920.12              0.00
# 12  1516.928620                1.0    3217.99           2500.23
#
#     INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2                     0.00           0.0             1.000000
# 5                  1333.28           0.0             0.666667
# 7                   436.20           0.0             1.000000
# 10                  920.12           0.0             1.000000
# 12                  717.76           0.0             1.000000
#
#     ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 2                         1.00                          0.000000
# 5                         0.00                          0.583333
# ...

# %%
cluster_2 = clustered_df[clustered_df['CLUSTER']==1]
cluster_2.head()
# Out:
#         BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6    627.260806                1.0    7091.01           6402.63
# 21  6369.531318                1.0    6359.95           5910.04
# 57  2386.330629                1.0    5217.62           4789.09
# 84  1935.362486                1.0    4915.60           4515.34
# 90  9381.255094                1.0    5100.07           1147.83
#
#     INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6                   688.38      0.000000             1.000000
# 21                  449.91    229.028245             1.000000
# 57                  428.53      0.000000             0.916667
# 84                  400.26    293.844792             1.000000
# 90                 3952.24    370.737197             1.000000
#
#     ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 6                     1.000000                          1.000000
# 21                    0.916667                          1.000000
# ...

# %%
cluster_3 = clustered_df[clustered_df['CLUSTER']==2]
cluster_3.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
# 8  1014.926473           1.000000     861.49            661.49
# 9   152.225975           0.545455    1281.60           1281.60
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
# 8                   200.0      0.000000             0.333333
# 9                     0.0      0.000000             0.166667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 3                    0.083333                          0.000000
# ...

# %%
cluster_4 = clustered_df[clustered_df['CLUSTER']==3]
cluster_4.head()
# Out:
#         BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1   3202.467416           0.909091       0.00              0.00
# 15  6886.213231           1.000000    1611.70              0.00
# 23  3800.151377           0.818182    4248.35           3454.56
# 24  5368.571219           1.000000       0.00              0.00
# 28  7152.864372           1.000000     387.05            204.55
#
#     INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                     0.00   6442.945483             0.000000
# 15                 1611.70   2301.491267             0.500000
# 23                  793.79   7974.415626             1.000000
# 24                    0.00    798.949863             0.000000
# 28                  182.50   2236.145259             0.666667
#
#     ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 1                     0.000000                          0.000000
# 15                    0.000000                          0.500000
# ...

# %% [markdown]
# ## plot the clusters

# %%
plt.figure(figsize=(7,7))
sns.countplot(x='CLUSTER',data=clustered_df, palette='Paired')
plt.title('Cluster Distribution')
plt.show()

# %%
for c in clustered_df.drop(['CLUSTER'],axis=1):
    grid= sns.FacetGrid(clustered_df, col='CLUSTER')
    grid= grid.map(plt.hist, c)
plt.show()

# %% [markdown]
# ## Save the model

# %%
import joblib
joblib.dump(kmeans_model, 'kmeans_model.pkl')
# Out:
# ['kmeans_model.pkl']

# %%
clustered_df.to_csv('clustered_data.csv',index=False)

# %% [markdown]
# ## Train the model

# %%
X = clustered_df.drop(['CLUSTER'],axis=1)
y = clustered_df['CLUSTER']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((6265, 17), (2685, 17), (6265,), (2685,))

# %%
X_train.head()
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 5831   649.896506           1.000000    4919.76           4353.06
# 2244  2382.328208           1.000000     899.58            413.28
# 4205  1119.157048           1.000000     133.90            133.90
# 7933     0.000000           0.000000     136.80              0.00
# 8462    20.620429           0.818182     169.66              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 5831                  566.70    191.376535             0.916667
# 2244                  486.30    450.252732             1.000000
# 4205                    0.00    269.234406             0.166667
# 7933                  136.80      0.000000             1.000000
# 8462                  169.66      0.000000             0.750000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 5831                    0.666667                          0.833333
# ...

# %%
X_test.head()
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 7669    16.834929           0.454545      15.00             15.00
# 6125   540.020858           1.000000     612.23            495.61
# 7028   119.237712           1.000000     342.74              0.00
# 3019   894.081947           1.000000    1901.71           1853.11
# 3479  1294.145453           1.000000    3059.10           1836.98
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 7669                    0.00    209.025389             0.090909
# 6125                  116.62   1708.923217             0.666667
# 7028                  342.74      0.000000             1.000000
# 3019                   48.60    206.618780             0.666667
# 3479                 1222.12      0.000000             1.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 7669                    0.090909                          0.000000
# ...

# %% [markdown]
# ## Model development

# %%
model = DecisionTreeClassifier(criterion='entropy')
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %% [markdown]
# ## Model evaluation

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94      1005
#            1       0.93      0.86      0.90       130
#            2       0.95      0.95      0.95      1204
#            3       0.87      0.87      0.87       346
#
#     accuracy                           0.93      2685
#    macro avg       0.92      0.91      0.92      2685
# weighted avg       0.93      0.93      0.93      2685

# %% [markdown]
# ### Confusion matrix

# %%
cm = metrics.confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 950    4   33   18]
#  [  15  112    2    1]
#  [  32    0 1148   24]
#  [  11    4   31  300]]

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(cm, annot=True, cmap='coolwarm', fmt='d')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### Save classification model

# %%
import pickle
pickle.dump(model, open('model.sav', 'wb'))

# %%
loaded_model = pickle.load(open('model.sav', 'rb'))
result = loaded_model.score(X_test, y_test)
print(result * 100, '% Accuracy')
# Out:
# 93.48230912476723 % Accuracy
